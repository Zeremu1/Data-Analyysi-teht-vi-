# %%
import pandas as pd

chipo = pd.read_csv('chip_dataset.csv', sep=',', encoding='utf-8')

# %%
# to display the first 10 rows of the Pandas DataFrame called chipo
chipo.head(10)
# Out:
#    Unnamed: 0                    Product Type Release Date  Process Size (nm)  \
# 0           0        AMD Athlon 64 3500+  CPU   20/02/2007               65.0
# 1           1           AMD Athlon 200GE  CPU   06/09/2018               14.0
# 2           2       Intel Core i5-1145G7  CPU   02/09/2020               10.0
# 3           3      Intel Xeon E5-2603 v2  CPU   01/09/2013               22.0
# 4           4    AMD Phenom II X4 980 BE  CPU   03/05/2011               45.0
# 5           5      Intel Xeon E5-2470 v2  CPU   01/09/2013               22.0
# 6           6  AMD Phenom X4 9750 (125W)  CPU   27/03/2008               65.0
# 7           7        Intel Pentium D 930  CPU   16/01/2006               65.0
# 8           8       Intel Core i3-1125G4  CPU   02/09/2020               10.0
# 9           9     AMD Athlon 64 X2 4200+  CPU   23/05/2006               90.0
#
#    TDP (W)  Die Size (mm^2)  Transistors (million)  Freq (MHz)  Foundry  \
# ...

# %%
# to display the first 10 rows of the Pandas DataFrame called chipo
chipo.shape[0]

# To provide a summary of information about the DataFrame chipo. It provides useful information such as data types and number of missing values.
chipo.info()

# To return the the number of rows and columns of the DataFrame.
chipo.shape

# To return the number of columns in the dataset
chipo.shape[1]

# To Print the name of all the columns.
chipo.columns

# To return the index labels used in the chipo DataFrame
chipo.index

# To return a two-dimensional NumPy array that contains the data stored in the DataFrame.
chipo.values

# Get data types of multiple columns
column_data_types = chipo.dtypes
print(column_data_types)

# Get data type of a single column
column_data_type = chipo['Transistors (million)'].dtype
print(column_data_type)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4854 entries, 0 to 4853
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             4854 non-null   int64
#  1   Product                4854 non-null   object
#  2   Type                   4854 non-null   object
#  3   Release Date           4854 non-null   object
#  4   Process Size (nm)      4845 non-null   float64
#  5   TDP (W)                4228 non-null   float64
#  6   Die Size (mm^2)        4139 non-null   float64
#  7   Transistors (million)  4143 non-null   float64
#  8   Freq (MHz)             4854 non-null   int64
#  9   Foundry                4854 non-null   object
#  10  Vendor                 4854 non-null   object
#  11  FP16 GFLOPS            536 non-null    float64
#  12  FP32 GFLOPS            1948 non-null   float64
#  13  FP64 GFLOPS            1306 non-null   float64
# ...

# %%
# sort_values sorts the item in ascending order based on the column Transistors
chipo.sort_values("Transistors (million)")
# Out:
#       Unnamed: 0                        Product Type Release Date  \
# 2688        2688                     ATI ES1000  GPU   18/10/2007
# 4845        4845             NVIDIA Tegra 3 GPU  GPU   09/11/2011
# 2992        2992      Matrox Millennium G450 LP  GPU          NaT
# 4842        4842  Matrox Millennium G450 x4 MMS  GPU   19/06/2002
# 2662        2662  Matrox Millennium G450 x2 MMS  GPU   19/06/2002
# ...          ...                            ...  ...          ...
# 4812        4812            NVIDIA GeForce 940A  GPU   13/03/2015
# 4815        4815             Intel GMA X4700MHD  GPU   01/10/2008
# 4819        4819            NVIDIA GeForce 940A  GPU   13/03/2015
# 4823        4823         NVIDIA GeForce 6150 LE  GPU   11/10/2004
# 4850        4850                  Intel GMA 950  GPU   01/06/2005
#
#       Process Size (nm)  TDP (W)  Die Size (mm^2)  Transistors (million)  \
# 2688              180.0      NaN             80.0                    8.0
# ...

# %%
# Sorting in Descending Order
chipo.sort_values("Transistors (million)", ascending=False)
# Out:
#       Unnamed: 0                 Product Type Release Date  Process Size (nm)  \
# 3156        3156       NVIDIA GRID A100B  GPU   14/05/2020                7.0
# 3134        3134  NVIDIA A100 SXM4 40 GB  GPU   14/05/2020                7.0
# 2942        2942       NVIDIA GRID A100A  GPU   14/05/2020                7.0
# 3911        3911        NVIDIA A100 PCIe  GPU   22/06/2020                7.0
# 2674        2674  NVIDIA A100 SXM4 80 GB  GPU   16/11/2020                7.0
# ...          ...                     ...  ...          ...                ...
# 4812        4812     NVIDIA GeForce 940A  GPU   13/03/2015               28.0
# 4815        4815      Intel GMA X4700MHD  GPU   01/10/2008               65.0
# 4819        4819     NVIDIA GeForce 940A  GPU   13/03/2015               28.0
# 4823        4823  NVIDIA GeForce 6150 LE  GPU   11/10/2004               90.0
# 4850        4850           Intel GMA 950  GPU   01/06/2005               90.0
#
# ...

# %%
# sorting by multiple columns
chipo.sort_values(["Transistors (million)", "Freq (MHz)"])
# Out:
#       Unnamed: 0                        Product Type Release Date  \
# 2688        2688                     ATI ES1000  GPU   18/10/2007
# 2662        2662  Matrox Millennium G450 x2 MMS  GPU   19/06/2002
# 2794        2794    Matrox Millennium G550 PCIe  GPU   26/11/2001
# 2992        2992      Matrox Millennium G450 LP  GPU          NaT
# 4185        4185         Matrox Millennium G550  GPU   26/11/2001
# ...          ...                            ...  ...          ...
# 2132        2132            Intel Core i7-7700K  CPU   03/01/2017
# 2153        2153       Intel Pentium Gold G6505  CPU   16/03/2021
# 237          237            Intel Core i7-7740X  CPU   26/06/2017
# 1115        1115       Intel Pentium Gold G6605  CPU   16/03/2021
# 1472        1472            Intel Core i3-7360X  CPU   03/10/2017
#
#       Process Size (nm)  TDP (W)  Die Size (mm^2)  Transistors (million)  \
# 2688              180.0      NaN             80.0                    8.0
# ...

# %%
# sorting by multiple columns : first descending and then in ascending order
chipo.sort_values(["Transistors (million)", "Freq (MHz)"], ascending=[False, True])
# Out:
#       Unnamed: 0                   Product Type Release Date  \
# 3911        3911          NVIDIA A100 PCIe  GPU   22/06/2020
# 2942        2942         NVIDIA GRID A100A  GPU   14/05/2020
# 3156        3156         NVIDIA GRID A100B  GPU   14/05/2020
# 2487        2487          NVIDIA PG506-232  GPU   12/04/2021
# 4450        4450           NVIDIA A30 PCIe  GPU   12/04/2021
# ...          ...                       ...  ...          ...
# 2132        2132       Intel Core i7-7700K  CPU   03/01/2017
# 2153        2153  Intel Pentium Gold G6505  CPU   16/03/2021
# 237          237       Intel Core i7-7740X  CPU   26/06/2017
# 1115        1115  Intel Pentium Gold G6605  CPU   16/03/2021
# 1472        1472       Intel Core i3-7360X  CPU   03/10/2017
#
#       Process Size (nm)  TDP (W)  Die Size (mm^2)  Transistors (million)  \
# 3911                7.0    250.0            826.0                54200.0
# 2942                7.0    400.0            826.0                54200.0
# ...

# %%
# selecting a single column called Transistors
subset_chipo = chipo["Transistors (million)"]
print(subset_chipo)
# Out:
# 0        122.0
# 1       4800.0
# 2          NaN
# 3       1400.0
# 4        758.0
#          ...
# 4849    1950.0
# 4850       NaN
# 4851     486.0
# 4852      29.0
# 4853     210.0
# Name: Transistors (million), Length: 4854, dtype: float64

# %%
# selecting multiple columns
subset_chipo1 = chipo[["Transistors (million)", "Freq (MHz)", "Vendor"]]
print(subset_chipo1)
# Out:
#       Transistors (million)  Freq (MHz)  Vendor
# 0                     122.0        2200     AMD
# 1                    4800.0        3200     AMD
# 2                       NaN        2600   Intel
# 3                    1400.0        1800   Intel
# 4                     758.0        3700     AMD
# ...                     ...         ...     ...
# 4849                 1950.0         450  NVIDIA
# 4850                    NaN         250   Intel
# 4851                  486.0         500  NVIDIA
# 4852                   29.0         250  NVIDIA
# 4853                  210.0         540  NVIDIA
#
# [4854 rows x 3 columns]

# %%
# getting items whose id is greater than 1000 (make sure the column's data type is integer)
subset_df = chipo[chipo['Unnamed: 0'] > 1000]
print(subset_df)
# Out:
#       Unnamed: 0                     Product Type Release Date  \
# 1001        1001                AMD A8-5550M  CPU   01/06/2013
# 1002        1002         Intel Core i5-8265U  CPU   01/10/2018
# 1003        1003        Intel Core i7-10875H  CPU   02/04/2020
# 1004        1004   AMD Athlon 64 X2 4000+ EE  CPU   23/05/2006
# 1005        1005  Intel Xeon Platinum 8360HL  CPU   06/04/2021
# ...          ...                         ...  ...          ...
# 4849        4849         NVIDIA Quadro 3000M  GPU   22/02/2011
# 4850        4850               Intel GMA 950  GPU   01/06/2005
# 4851        4851      NVIDIA GeForce GT 320M  GPU   03/03/2010
# 4852        4852      NVIDIA GeForce FX 5200  GPU   06/03/2003
# 4853        4853      NVIDIA GeForce 9300 SE  GPU   01/06/2008
#
#       Process Size (nm)  TDP (W)  Die Size (mm^2)  Transistors (million)  \
# 1001               32.0     35.0            246.0                 1178.0
# ...

# %%
# subsetting based on text data
subset_df = chipo[chipo['Vendor'] == "AMD"]
print(subset_df)
# Out:
#       Unnamed: 0                    Product Type Release Date  \
# 0              0        AMD Athlon 64 3500+  CPU   20/02/2007
# 1              1           AMD Athlon 200GE  CPU   06/09/2018
# 4              4    AMD Phenom II X4 980 BE  CPU   03/05/2011
# 6              6  AMD Phenom X4 9750 (125W)  CPU   27/03/2008
# 9              9     AMD Athlon 64 X2 4200+  CPU   23/05/2006
# ...          ...                        ...  ...          ...
# 4829        4829      AMD Radeon R5 220 OEM  GPU   21/12/2013
# 4830        4830  AMD Radeon RX 550X Mobile  GPU   11/04/2018
# 4833        4833        AMD Radeon R9 280X2  GPU          NaT
# 4836        4836   AMD Radeon Instinct MI25  GPU   27/06/2017
# 4839        4839    AMD Radeon R7 350 640SP  GPU   07/01/2019
#
#       Process Size (nm)  TDP (W)  Die Size (mm^2)  Transistors (million)  \
# 0                  65.0     45.0             77.0                  122.0
# ...

# %%
# subsetting with mulitple conditions
subset_df1 = chipo['Unnamed: 0'] > 1000
subset_df2 = chipo['Vendor'] == "AMD"
subset_df3 = chipo[subset_df1 & subset_df2]
subset_df3.head()
# Out:
#       Unnamed: 0                    Product Type Release Date  \
# 1001        1001               AMD A8-5550M  CPU   01/06/2013
# 1004        1004  AMD Athlon 64 X2 4000+ EE  CPU   23/05/2006
# 1006        1006           AMD A6-9220C SoC  CPU   07/01/2019
# 1009        1009          AMD Sempron 2800+  CPU   01/01/2001
# 1012        1012     AMD Athlon 64 X2 4000+  CPU   05/12/2006
#
#       Process Size (nm)  TDP (W)  Die Size (mm^2)  Transistors (million)  \
# 1001               32.0     35.0            246.0                 1178.0
# 1004               90.0     65.0            220.0                  154.0
# 1006               28.0      6.0            124.0                 1200.0
# 1009              130.0     25.0            144.0                   69.0
# 1012               65.0     65.0            126.0                  154.0
#
#       Freq (MHz)  Foundry Vendor  FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS
# 1001        2100  Unknown    AMD          NaN          NaN          NaN
# ...

# %%
# if you check the data type for item_price column it is object and therefore we need to change the data type to float or integer to perform calculations
print(chipo['Transistors (million)'].dtype)
# Out:
# float64

# %%
# Now lets make a new column called total by multiplying 'quantity' and 'item_price'
chipo['total'] = chipo['Freq (MHz)'] * chipo['Transistors (million)']

# lets check if we have the new column total
chipo.head(20)
# Out:
#     Unnamed: 0                    Product Type Release Date  \
# 0            0        AMD Athlon 64 3500+  CPU   20/02/2007
# 1            1           AMD Athlon 200GE  CPU   06/09/2018
# 2            2       Intel Core i5-1145G7  CPU   02/09/2020
# 3            3      Intel Xeon E5-2603 v2  CPU   01/09/2013
# 4            4    AMD Phenom II X4 980 BE  CPU   03/05/2011
# 5            5      Intel Xeon E5-2470 v2  CPU   01/09/2013
# 6            6  AMD Phenom X4 9750 (125W)  CPU   27/03/2008
# 7            7        Intel Pentium D 930  CPU   16/01/2006
# 8            8       Intel Core i3-1125G4  CPU   02/09/2020
# 9            9     AMD Athlon 64 X2 4200+  CPU   23/05/2006
# 10          10          AMD Sempron 2800+  CPU   01/08/2004
# 11          11       Intel Core i7-3632QM  CPU   19/10/2012
# 12          12                   AMD C-70  CPU   01/09/2012
# 13          13        Intel Core i5-8269U  CPU   05/04/2018
# 14          14      AMD Phenom X4 9600 BE  CPU   19/12/2007
# ...

# %%
# first lets create a function to define the price ranges
def categorize_price(Transistors):
    if Transistors < 500:
        return 'Low'
    elif Transistors < 2500:
        return 'Medium'
    else:
        return 'High'
# We can use the .apply() method to create a new column 'price_group' based on the 'item_price' column.
chipo['transistor_count'] = chipo['Transistors (million)'].apply(categorize_price)
chipo.head()
# Out:
#    Unnamed: 0                  Product Type Release Date  Process Size (nm)  \
# 0           0      AMD Athlon 64 3500+  CPU   20/02/2007               65.0
# 1           1         AMD Athlon 200GE  CPU   06/09/2018               14.0
# 2           2     Intel Core i5-1145G7  CPU   02/09/2020               10.0
# 3           3    Intel Xeon E5-2603 v2  CPU   01/09/2013               22.0
# 4           4  AMD Phenom II X4 980 BE  CPU   03/05/2011               45.0
#
#    TDP (W)  Die Size (mm^2)  Transistors (million)  Freq (MHz)  Foundry  \
# 0     45.0             77.0                  122.0        2200  Unknown
# 1     35.0            192.0                 4800.0        3200  Unknown
# 2     28.0              NaN                    NaN        2600    Intel
# 3     80.0            160.0                 1400.0        1800    Intel
# 4    125.0            258.0                  758.0        3700  Unknown
#
# ...
